# %%
from example_project.dataset import load_data

data = load_data()
data
# Out:
#        Data
# Time
# 00:00   1.2
# 00:10   2.0
# 00:20   1.5

# %%
import plotly.express as px

fig = px.line(data)
fig

# %%
from example_project.config import REPORTS_DIR, FIGURES_DIR

fig.write_image(FIGURES_DIR / "data.png")
fig.write_html(REPORTS_DIR / "data.html")
